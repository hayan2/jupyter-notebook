# %%
import pandas as pd
import seaborn as sns
mpg = sns.load_dataset('mpg')
mpg.shape
# Out:
# (398, 9)

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.sort_values('mpg')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 325  44.3          4          90.0        48.0    2085          21.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year  origin                  name
# 28           70     usa              hi 1200d
# ...

# %%
mpg.sort_values('mpg', ascending = False).head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)

# %%
mpg['mpg'].sort_values()
# Out:
# 28      9.0
# 25     10.0
# 26     10.0
# 103    11.0
# 124    11.0
#        ...
# 326    43.4
# 394    44.0
# 325    44.3
# 329    44.6
# 322    46.6
# Name: mpg, Length: 398, dtype: float64

# %%
mpg.sort_index()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.reset_index()
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0        0  18.0          8         307.0       130.0    3504          12.0
# 1        1  15.0          8         350.0       165.0    3693          11.5
# 2        2  18.0          8         318.0       150.0    3436          11.0
# 3        3  16.0          8         304.0       150.0    3433          12.0
# 4        4  17.0          8         302.0       140.0    3449          10.5
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    393  27.0          4         140.0        86.0    2790          15.6
# 394    394  44.0          4          97.0        52.0    2130          24.6
# 395    395  32.0          4         135.0        84.0    2295          11.6
# 396    396  28.0          4         120.0        79.0    2625          18.6
# 397    397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# ...

# %%
mpg = mpg.set_index('name')
mpg
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
mpg.sort_index()
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# name
# amc ambassador brougham  13.0          8         360.0       175.0    3821
# amc ambassador dpl       15.0          8         390.0       190.0    3850
# amc ambassador sst       17.0          8         304.0       150.0    3672
# amc concord              24.3          4         151.0        90.0    3003
# amc concord              19.4          6         232.0        90.0    3210
# ...                       ...        ...           ...         ...     ...
# vw pickup                44.0          4          97.0        52.0    2130
# vw rabbit                41.5          4          98.0        76.0    2144
# vw rabbit                29.0          4          90.0        70.0    1937
# vw rabbit c (diesel)     44.3          4          90.0        48.0    2085
# vw rabbit custom         31.9          4          89.0        71.0    1925
#
#                          acceleration  model_year  origin
# ...

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.sort_values('passengers')
# Out:
#      year month  passengers
# 10   1949   Nov         104
# 0    1949   Jan         112
# 22   1950   Nov         114
# 12   1950   Jan         115
# 1    1949   Feb         118
# ..    ...   ...         ...
# 137  1960   Jun         535
# 126  1959   Jul         548
# 127  1959   Aug         559
# 139  1960   Aug         606
# 138  1960   Jul         622
#
# [144 rows x 3 columns]

# %%
flights.sort_index().tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %% [markdown]
# > ## 연습 3-4-1-가

# %%
f = { 'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
      'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
      'rating': [4, 4, 3.5, 15, 5] 
}
food = pd.DataFrame(f)
food
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
food.sort_values('rating')
# Out:
#      brand style  rating
# 2  Indomie   cup     3.5
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 4  Indomie  pack     5.0
# 3  Indomie  pack    15.0

# %%
food = food.set_index('brand')
food
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 food = food.set_index('brand')
#       2 food
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# -> 6012     raise KeyError(f"None of {missing} are in the columns")
#    6014 if inplace:
# ...

# %%
food.sort_index()
# Out:
#         style  rating
# brand
# Indomie   cup     3.5
# Indomie  pack    15.0
# Indomie  pack     5.0
# Yum Yum   cup     4.0
# Yum Yum   cup     4.0

# %%
df.drop(columns = ['mpg', 'cylinders'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.drop(columns = ['mpg', 'cylinders'])
#
# NameError: name 'df' is not defined

# %%
df.drop('mpg', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.drop('mpg', axis = 1)
#
# NameError: name 'df' is not defined

# %%
df.drop(index = 'buick skylark 320')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop(index = 'buick skylark 320')
#
# NameError: name 'df' is not defined

# %%
df.drop(['chevolet chevelle malibu', 'plymouth satellite'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.drop(['chevolet chevelle malibu', 'plymouth satellite'])
#
# NameError: name 'df' is not defined

# %%
flights.drop('year', axis = 1).head(3)
# Out:
#   month  passengers
# 0   Jan         112
# 1   Feb         118
# 2   Mar         132

# %%
flights.drop(index = [3, 6]).head(7)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 4  1949   May         121
# 5  1949   Jun         135
# 7  1949   Aug         148
# 8  1949   Sep         136
